# %% [markdown]
# <a href="https://colab.research.google.com/github/anandyadavanshi074-lgtm/Data-science/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = input("Enter a string: ")
i=0
j=len(s)-1

while(i<j)
# Out:
# Enter a string: 121
# The string '121' is a palindrome.

# %%
lst=[3,4,23,4,2]
# lst.sort()

# find sum,max and min;
print(sum(lst))
print(max(lst))
print(min(lst))



print(lst)
#make a new sort array;
s=sorted(lst)
print(lst)
print(s)
# Out:
# 36
# 23
# 2
# [3, 4, 23, 4, 2]
# [3, 4, 23, 4, 2]
# [2, 3, 4, 4, 23]

# %%
#tupple
tp=(2,3,1,4,5,2)
a=tuple(sorted(tp))
#return a list;
print(a)


print(max(tp))
print(min(tp))
print(sum(tp))
a=5
a
print(tp.index(4))
sum=0
sum
# Out:
# (1, 2, 2, 3, 4, 5)
# 5
# 1
# 17
# 3
# 0

# %%
lst=[2,3,4,2,12]
lst2=[3,4,2,2,15]
i=0
n=len(lst)


while(i<n):
  lst[i]=lst[i]+lst2[i]
  i=i+1
print(lst)
# Out:
# [5, 7, 6, 4, 27]

# %%
lst=[]
i=0
while(i<5):
 append(
      lst.append(i)
 )
  i=i+1

print(lst)
# Out:
#   File "/tmp/ipykernel_7158/669457461.py", line 7
#     i=i+1
#     ^
# IndentationError: unexpected indent

# %%
int(input())
lst=[]
lst2=[]

for i in range(n):
  lst.append(int(input()))
print(lst)
# Out:
# 5
# 3
# 2
# 2
# 3
# 4
# [3, 2, 2, 3, 4]
