# %% [markdown]
# <a href="https://colab.research.google.com/github/anandyadavanshi074-lgtm/Data-science/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PANDAS**

# %%
import pandas as pd;
dict ={
    'name':['tom','nick','alex','jack'],
    'age':[20,21,19,18],
    'roll':[1,2,3,4]
}

df=pd.DataFrame(dict,index=['1','2','3','4']),
df1=pd.DataFrame(dict)
print(df)
df
display(df)
display(df1)
# Out:
# (   name  age  roll
# 1   tom   20     1
# 2  nick   21     2
# 3  alex   19     3
# 4  jack   18     4,)
# (   name  age  roll
#  1   tom   20     1
#  2  nick   21     2
#  3  alex   19     3
#  4  jack   18     4,)
#    name  age  roll
# 0   tom   20     1
# 1  nick   21     2
# 2  alex   19     3
# 3  jack   18     4

# %% [markdown]
# to read data **use**

# %%
df=pd.read_csv('PANDASss.csv')
df.head() #use to read first five data ;
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
# 3            8          99            9               8
# 4            5          52            8               6
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62      100.00           Placed
# 1                      8              56      100.00           Placed
# 2                     10              45      100.00           Placed
# 3                      4              55       90.17           Placed
# 4                      8              40       78.82           Placed

# %%
df=pd.read_csv('PANDASss.csv')
df.info()

#get a info about a data of data =meta deta;
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   study_hours            10000 non-null  int64
#  1   attendance             10000 non-null  int64
#  2   sleep_hours            10000 non-null  int64
#  3   internet_usage         10000 non-null  int64
#  4   assignments_completed  10000 non-null  int64
#  5   previous_score         10000 non-null  int64
#  6   exam_score             10000 non-null  float64
#  7   placement_status       10000 non-null  object
# dtypes: float64(1), int64(6), object(1)
# memory usage: 625.1+ KB

# %%
df=pd.read_csv('PANDASss.csv')
# df.describe()

# df.index

# df[['study_hours','internet_uses']]
# df['study_hours']
# df.iloc[0]#to acces of row
# df.iloc[0:3]

df.loc[df['study_hours']==11,['study_hours']]

df.loc[4]
# Out:
# study_hours                   5
# attendance                   52
# sleep_hours                   8
# internet_usage                6
# assignments_completed         8
# previous_score               40
# exam_score                78.82
# placement_status         Placed
# Name: 4, dtype: object

# %% [markdown]
# # loc are use to follow a condition
# iloc are use to acces a index
#
# iloc make a own index;
#
# #loc are acces by level

# %%
df=pd.read_csv('PANDASss.csv')


df.loc[df["assignments_completed"]==8].iloc[1]
# Out:
# study_hours                   5
# attendance                   52
# sleep_hours                   8
# internet_usage                6
# assignments_completed         8
# previous_score               40
# exam_score                78.82
# placement_status         Placed
# Name: 4, dtype: object

# %%
df=pd.read_csv('PANDASss.csv')

df[df["assignments_completed"]>3]



# df["age"]=20 if
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
df=pd.read_csv('PANDASss.csv')

# rename colomns

df.rename(columns={'assignments_completed':'assing_completed'},inplace=True)
df
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assing_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...

# %%
df=pd.read_csv('PANDASss.csv')

df.drop(columns='internet_usage')
#remove colomns;
#remove row use=(2);
# df.sort_index()
# df.sort_values('internet_usage')
# Out:
#       study_hours  attendance  sleep_hours  assignments_completed  \
# 0               7          56            8                     10
# 1               4          69            5                      8
# 2              11          60            7                     10
# 3               8          99            9                      4
# 4               5          52            8                      8
# ...           ...         ...          ...                    ...
# 9995            2          58            9                      8
# 9996            7          98            6                      4
# 9997           10          44            8                     10
# 9998           10          75            7                      8
# 9999            2          70            6                     16
#
#       previous_score  exam_score placement_status
# 0                 62      100.00           Placed
# 1                 56      100.00           Placed
# ...
